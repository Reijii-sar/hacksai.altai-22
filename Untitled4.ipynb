# %% [markdown]
# ### Задача
# На основе данных об абитуриенте необходимо разработать модель, которая будет предсказывать текущий статус студента, а именно:
# - продолжит ли студент обучение
# - отчислится
# - возьмет академический отпуск
#
# ### Описание входных значений:
# - ID - персональный идентификатор абитуриента
# - Код_группы - идентификатор группы
# - Год_Поступления - год поступления абитуриента
# - Пол - пол абитуриента, имеет идентификаторы: Муж, Жен
# - Основания - основания поступления абитуриента. Имеются следующие значения: СН - специальный набор, ЦН - целевой набор, БН - бюджетный набор, ОО - общие основания, ДН - дополнительный прием
# - Изучаемый_Язык - иностранный язык, который изучался абитуриентом. Поскольку долгое время данное поле было полем ввода, то происходит **дублирование значений**.
# - Дата_Рождения - дата рождения абитуриента
# - Уч_Заведение - наименование учебного заведения
# - Где_Находится_УЗ - локация учебного заведения. **Структура данного поля разнообразна**, может происходить наименование города, а может указываться область+город или даже страна+область+город.
# - Год_Окончания_УЗ - год окончания учебного заведения
# - Пособие - получает ли абитуриент пособия. Возможные значения:0 - абитуриент не получает пособие, 1 - абитуриент получает пособие
# - Страна_ПП - страна постоянного проживания. Поскольку долгое время данное поле было полем ввода, то происходит **дублирование значений**.
# - Регион_ПП - регион постоянного проживания. Поскольку долгое время данное поле было полем ввода, то происходит **дублирование значений**.
# - Город_ПП - город постоянного проживания. Поскольку долгое время данное поле было полем ввода, то происходит **дублирование значений**.
# - Общежитие - требуется ли общежитие абитуриенту. Возможные значения: 0 - абитуриенту не требуется общежитие, 1 - абитуриенту требуется общежитие
# - Наличие_Матери - поле, показывающие наличие матери. Возможные значения: 0 - у абитуриента нет матери, 1 - у абитуриента есть мать
# - Наличие_Отца - поле, показывающие наличие отца. Возможные значения: 0 - у абитуриента нет отца, 1 - у абитуриента есть отец
# - Страна_Родители - страна постоянного проживания родителей
# - Опекунство - является ли абитуриент опекаемым. Возможные значения: 0 - абитуриент не является опекаемым, 1 - абитуриент является опекаемым
# - Село - проживает ли абитуриент в сельской местности. Возможные значения: 0 - абитуриент не проживает в сельской местности, 1 -абитуриент проживает в сельской местности
# - Иностранец - является ли абитуриент иностранным студентом. Возможные значения: 0 - абитуриент не является иностранцем, 1 - абитуриент является иностранцем
# - КодФакультета - идентификатор факультета
# - СрБаллАттестата - средний балл аттестата или средний балл ЕГЭ. Зависит от того, сдавал ли абитуриент ЕГЭ
# - Статус (**целевая переменная**) - статус студента. Возможные значения: -1 – ушел в академический отпуск, 4 – закончил обучение, 3 – отчислен, 5 – призван в армию
#
# ### Метрика:
# В качестве метрики выступает F1-мера

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from catboost import CatBoostClassifier, Pool
from sklearn.utils import shuffle, compute_class_weight
import warnings
import time
from IPython.display import display_html
from itertools import chain,cycle

# %%
warnings.filterwarnings('ignore')
#pd.set_option('display.max_colwidth', None) #выводим на экран весь текст из колонки
pd.set_option('display.max_rows', None) #выводим на экран все строки
pd.set_option('display.max_columns', None) #выводим на экран все колонки

# %%
df_train = pd.read_csv('train_dataset_train.csv')
df_test = pd.read_csv('test_dataset_test.csv')
df_submission = pd.read_csv('sample_submission.csv')

id_language = pd.read_csv('id_language.csv')
id_country = pd.read_csv('id_country.csv')

# %%
#вывод нескольких экранов рядом
def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2 style="text-align: center;">{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# %%
train = df_train.copy()
test = df_test.copy()

# %%
train.head()
# Out:
#       ID  Код_группы  Год_Поступления  Пол Основания   Изучаемый_Язык  \
# 0  72716       16019             2015  Жен        ОО  Английский язык
# 1  63306       14895             2010  Муж        ЦН              NaN
# 2  82469       20103             2017  Жен        ДН  Английский язык
# 3  81661       19838             2017  Жен        БН  Английский язык
# 4  81509       19803             2017  Жен        БН  Английский язык
#
#              Дата_Рождения                                    Уч_Заведение  \
# 0  1998-02-08 00:00:00.000                                  МБОУ "СОШ №59"
# 1  1992-04-18 00:00:00.000                                             NaN
# 2  1999-03-21 00:00:00.000                           МБОУ Алтайская СОШ №5
# 3  1994-12-08 00:00:00.000  ФГБОУ ВО Алтайский государственный университет
# 4  1995-06-28 00:00:00.000  ФГБОУ ВО Алтайский государственный университет
#
#                              Где_Находится_УЗ  Год_Окончания_УЗ  Пособие  \
# 0                   Алтайский край, Барнаул г            2014.0      0.0
# 1                                         NaN               NaN      0.0
# 2  Алтайский край, Алтайский р-н, Алтайское с            2017.0      0.0
# 3                  Алтайский край, г. Барнаул            2017.0      0.0
# 4                  Алтайский край, г. Барнаул            2017.0      0.0
#
#   Страна_ПП       Регион_ПП     Город_ПП  Общежитие  Наличие_Матери  \
# 0    Россия  Алтайский край    Барнаул г        0.0               0
# 1    Россия  Алтайский край    Барнаул г        0.0               1
# 2    Россия  Алтайский край  Алтайское с        0.0               1
# 3    Россия  Алтайский край   г. Барнаул        0.0               1
# 4    Россия  Алтайский край   г. Барнаул        0.0               1
#
#    Наличие_Отца Страна_Родители  Опекунство  Село  Иностранец  КодФакультета  \
# 0           0.0          Россия         0.0   0.0         0.0           41.0
# 1           1.0          Россия         0.0   0.0         0.0           28.0
# 2           1.0          Россия         0.0   0.0         0.0           41.0
# 3           1.0          Россия         0.0   0.0         0.0           35.0
# 4           1.0          Россия         0.0   0.0         0.0           28.0
#
#    СрБаллАттестата  Статус
# 0            4.294       3
# 1           67.000       4
# 2            4.133       4
# 3           74.000       4
# 4           53.000       4

# %%
train.columns.values
# Out:
# array(['ID', 'Код_группы', 'Год_Поступления', 'Пол', 'Основания',
#        'Изучаемый_Язык', 'Дата_Рождения', 'Уч_Заведение',
#        'Где_Находится_УЗ', 'Год_Окончания_УЗ', 'Пособие', 'Страна_ПП',
#        'Регион_ПП', 'Город_ПП', 'Общежитие', 'Наличие_Матери',
#        'Наличие_Отца', 'Страна_Родители', 'Опекунство', 'Село',
#        'Иностранец', 'КодФакультета', 'СрБаллАттестата', 'Статус'],
#       dtype=object)

# %%
plt.rcParams['figure.figsize']=(15,15)

df_corr = list(set(train.columns.values))
sns.heatmap(train[df_corr].corr(), square = True, annot=True)
# Out:
# <AxesSubplot:>

# %%
#объеденим 2 датасета для общей обработки
#train = pd.concat([train, test], axis=0)
#train = train.reset_index(drop=True)
#train.shape

# %%
#train.dropna(subset=['Уч_Заведение','Где_Находится_УЗ','Год_Окончания_УЗ'], how='all')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13584 entries, 0 to 13583
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                13584 non-null  int64
#  1   Код_группы        13584 non-null  int64
#  2   Год_Поступления   13584 non-null  int64
#  3   Пол               13577 non-null  object
#  4   Основания         13584 non-null  object
#  5   Изучаемый_Язык    12758 non-null  object
#  6   Дата_Рождения     13584 non-null  object
#  7   Уч_Заведение      12351 non-null  object
#  8   Где_Находится_УЗ  12203 non-null  object
#  9   Год_Окончания_УЗ  12284 non-null  float64
#  10  Пособие           12576 non-null  float64
#  11  Страна_ПП         13237 non-null  object
#  12  Регион_ПП         12966 non-null  object
#  13  Город_ПП          13141 non-null  object
#  14  Общежитие         13498 non-null  float64
#  15  Наличие_Матери    13584 non-null  int64
#  16  Наличие_Отца      13584 non-null  float64
#  17  Страна_Родители   13126 non-null  object
#  18  Опекунство        13584 non-null  float64
#  19  Село              13498 non-null  float64
#  20  Иностранец        13274 non-null  float64
#  21  КодФакультета     13584 non-null  float64
#  22  СрБаллАттестата   13584 non-null  float64
#  23  Статус            13584 non-null  int64
# dtypes: float64(9), int64(5), object(10)
# memory usage: 2.5+ MB

# %%
def years_now (data):
    data['Дата_Рождения'] = pd.to_datetime(data['Дата_Рождения'])
    data['Возраст'] = (pd.to_datetime("today") - data['Дата_Рождения']).astype('<m8[Y]')
    data['Возраст'] = data['Возраст'].astype('int')
    data = data.drop('Дата_Рождения', axis=1)
    data.loc[(data['Возраст'] < 17), ['Возраст']] = data['Возраст'] + 10
    return data

train = years_now (train)
test = years_now (test)

# %%
train.columns.values
# Out:
# array(['ID', 'Код_группы', 'Год_Поступления', 'Пол', 'Основания',
#        'Изучаемый_Язык', 'Уч_Заведение', 'Где_Находится_УЗ',
#        'Год_Окончания_УЗ', 'Пособие', 'Страна_ПП', 'Регион_ПП',
#        'Город_ПП', 'Общежитие', 'Наличие_Матери', 'Наличие_Отца',
#        'Страна_Родители', 'Опекунство', 'Село', 'Иностранец',
#        'КодФакультета', 'СрБаллАттестата', 'Статус', 'Возраст'],
#       dtype=object)

# %%
train.loc[(train['Год_Поступления'] == 2212), 'Год_Поступления'] = 2012
train.loc[(train['Пол'] == 'муж'), 'Пол'] = 'Муж'
train.loc[(train['Пол'] == 'жен'), 'Пол'] = 'Жен'
test.loc[(test['Пол'] == 'муж'), 'Пол'] = 'Муж'
test.loc[(test['Пол'] == 'жен'), 'Пол'] = 'Жен'
test.loc[(test['Основания'] == 'ЛН'), 'Основания'] = 'ДН'
train['Пол'] = train['Пол'].fillna('Муж')
test['Пол'] = test['Пол'].fillna('Муж')

# %%
#Заменяем опечатки 
def df_text (data, text, column):
    for i in range(len(text['old'])):
        data.loc[(data[column] == text['old'][i]), column] = text['new'][i]
    data.loc[(data[column] == 'КИТАЙ'), column] = 'Китай'
    data[column] = data[column].fillna('нет')
    return data

# %%
train = df_text(train, id_country, 'Страна_ПП') 
train = df_text(train, id_country, 'Страна_Родители') 
train = df_text(train, id_language, 'Изучаемый_Язык')
test = df_text(test, id_country, 'Страна_ПП') 
test = df_text(test, id_country, 'Страна_Родители') 
test = df_text(test, id_language, 'Изучаемый_Язык')

# %%
# %%time
def finish_start (data):
    data.loc[((data['Год_Поступления'] - data['Год_Окончания_УЗ']) < 0),'Год_Поступления'] = data['Год_Окончания_УЗ']
    return data

train = finish_start (train)
test = finish_start (test)
# Out:
# Wall time: 8.87 ms

# %%
# %%time
def finish_school (data):
    data.loc[((data['Год_Окончания_УЗ'] - (2022-data['Возраст'])) < 15), 'Возраст'] = data['Возраст'] + 10
    return data

train = finish_school (train)
test = finish_school (test)
# Out:
# Wall time: 4 ms

# %%
train = train.drop('Пособие', axis=1)
test = test.drop('Пособие', axis=1)
train['Общежитие'] = train['Общежитие'].fillna(0)
test['Общежитие'] = test['Общежитие'].fillna(0)
#train['Год_Окончания_УЗ'] = train['Год_Поступления'].fillna(0)
#test['Год_Окончания_УЗ'] = test['Год_Поступления'].fillna(0)

# %%
def parents (data):
    data['Семья'] = data['Опекунство'] + data['Наличие_Матери']+data['Наличие_Отца']
    data.loc[(data['Семья'] != 1), 'Семья'] = 0
    data = data.drop(['Опекунство','Наличие_Матери','Наличие_Отца'], axis=1)
    return data

train = parents(train)
test = parents(test)

# %%
# %%time
def score (data):
    for i in range(len(data['СрБаллАттестата'])):
        if data['СрБаллАттестата'][i] <= 5:
            data['СрБаллАттестата'][i] = data['СрБаллАттестата'][i] *1000
        elif data['СрБаллАттестата'][i] > 100:
            data['СрБаллАттестата'][i] = data['СрБаллАттестата'][i]
        else:
            data['СрБаллАттестата'][i] = data['СрБаллАттестата'][i] *50
    return data
            
train = score (train)
test = score (test)
# Out:
# Wall time: 9.37 s

# %%
train.loc[(train['СрБаллАттестата'] == 0), 'СрБаллАттестата'] = train['СрБаллАттестата'].mean()
test.loc[(test['СрБаллАттестата'] == 0), 'СрБаллАттестата'] = test['СрБаллАттестата'].mean()

# %%
#создаем категорию по уровню образования (0 - нет данных, 1-среднее, 2-средне-специальное, 3-высшее)
#потом ручная правка выпавших значений
train['Ур_образования'] = 0
test['Ур_образования'] = 0
def id_edu (data, words, marker):
    for i in words:
        data['Ур_образования'][data['Уч_Заведение'].astype(str).str.contains(i, case=False)] = marker
    return data

edu_1 = ['сош','школ','гимназ','кош ','косш ','косшг',' сш','ксш',' мосш','cn',' осш','сш №', 'оош', 'c№', 'с№','Бригантина',
         ' ош ','ООШ','планета','общеобраз','сопш','СШ','МССОМШ','СОПШ','кадет','СОМШ','Новотырышкинская ОШ','ООУ №57','ГБОУШ',
         'УВК ШГ','сменная','вечерняя','Малышево-','Центр образования','Пенджик','Гиназия','О№57','СОУ №',
         'ОШ №','гамназия','ООУ №2','Царицино','СОМ №','КГОШ','Быстроистокская']    
edu_2 = ['лицей','пту','колледж','олимп','техникум','училище',' пу ','пу№','пу №','апэк','АКПЛ','летной','техниккум',
         'коледж','Сигма','коллеж','БКТАКПС','лицея','коллдеж','КемГППК','АТИВТ','ПУ г Камен','ПУ-30 ','Алтайский МТТ',
         'комбинат','СХТ','АСПО','СПН','ББМК','НПО ПЛ','ПЛ-39','БГПК','АМТТ МП','ПУ г. Камень', 'АГК','облпотреб']
edu_3 = ['универси','универст','унвиерс','институт','акаде','ааск','алгту',' гупс',' нигу','фамтт','агау','мэси','кбюи','БПГУ',
         ' тгу','гагу','консерв','фагу','ааэп','кемгу','агту','ГТУ','ВЗФИ','АГПА','АлтГУ','АГУ','АГИМ','БЮИ','СГА','иститу',
         'АГим','НИНХ','ВЗФЭИ','унивес','МАП при','агентства','АГАО','РХБЗ','унивкрс','ААЭиП','РГСУ','БГПУ','АЭЮИ','НГУ',
         'ФАГК','ТГУ','МГУ культуры','СУНЦ','аквдемия','СГГА','ВО НГИИ']

# %%
# %%time
train = id_edu (train, edu_1, 1)
train = id_edu (train, edu_2, 2)
train = id_edu (train, edu_3, 3)
train = train.drop('Уч_Заведение', axis=1)
# Out:
# Wall time: 26.7 s

# %%
# %%time
test = id_edu (test, edu_1, 1)
test = id_edu (test, edu_2, 2)
test = id_edu (test, edu_3, 3)
test = test.drop('Уч_Заведение', axis=1)
# Out:
# Wall time: 13.6 s

# %%
train['Год_Окончания_УЗ'] = train['Год_Окончания_УЗ'].fillna(train['Год_Поступления'])
test['Год_Окончания_УЗ'] = test['Год_Окончания_УЗ'].fillna(test['Год_Поступления'])

# %%
# %%time
train['Между_поступлениями'] = None
test['Между_поступлениями'] = None
def wait (data):
    for i in range(len(data['Год_Поступления'])):
        data['Между_поступлениями'][i] = data['Год_Поступления'][i]-data['Год_Окончания_УЗ'][i]
    return data
train = wait(train)
test = wait(test)
# Out:
# Wall time: 9.9 s

# %%
# %%time
def alien(data):
    data.loc[(data['Страна_ПП'] == 'нет'), 'Иностранец'] = 0
    data['Иностранец'] = data['Иностранец'].fillna(100)
    for i in range(len(data['Иностранец'])):       
        if (data['Иностранец'][i] == 100) & (data['Страна_ПП'][i] != 'Россия'):
            data['Иностранец'][i]  = 1
        elif (data['Иностранец'][i] == 100) & (data['Страна_ПП'][i] == 'Россия'):
            data['Иностранец'][i]  = 0                                   
    return data

train = alien(train)
test = alien(test)


#train.loc[(train['Страна_ПП'] != 'Россия'), 'Иностранец'] = 1
#train.loc[(train['Страна_ПП'] == 'нет'), 'Иностранец'] = 0 
#test.loc[(test['Страна_ПП'] != 'Россия'), 'Иностранец'] = 1
#test.loc[(test['Страна_ПП'] == 'нет'), 'Иностранец'] = 0
# Out:
# Wall time: 1.12 s

# %%
train['Село'] = train['Село'].fillna(0)
test['Село'] = test['Село'].fillna(0)

# %%
df_1 = train[train['Статус'] == -1]
df_3 = train[train['Статус'] == 3]
df_4 = train[train['Статус'] == 4]
df = train.copy()

# %%
def pie (data, column):
    global train
    new = pd.DataFrame(data[column].value_counts())
    new['local_%'] = new[column]/new[column].sum()
    new['global_%'] = new[column]/len(train[column])
    return new

# %%
display_side_by_side (pie (df, 'Основания'),pie (df_1, 'Основания'),
                      pie (df_3, 'Основания'),pie (df_4, 'Основания'),
                      titles=['Общая','Академ','Отчислен','Закончил'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Общая</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Основания</th>
#       <th>local_%</th>
#       <th>global_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ОО</th>
#       <td>5084</td>
#       <td>0.374264</td>
#       <td>0.374264</td>
#     </tr>
#     <tr>
#       <th>СН</th>
#       <td>4558</td>
#       <td>0.335542</td>
#       <td>0.335542</td>
#     </tr>
#     <tr>
#       <th>БН</th>
#       <td>1882</td>
#       <td>0.138545</td>
#       <td>0.138545</td>
#     </tr>
#     <tr>
#       <th>ДН</th>
#       <td>1853</td>
#       <td>0.136410</td>
#       <td>0.136410</td>
#     </tr>
#     <tr>
#       <th>ЦН</th>
#       <td>207</td>
#       <td>0.015239</td>
#       <td>0.015239</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Академ</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Основания</th>
#       <th>local_%</th>
#       <th>global_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ОО</th>
#       <td>265</td>
#       <td>0.431596</td>
#       <td>0.019508</td>
#     </tr>
#     <tr>
#       <th>СН</th>
#       <td>246</td>
#       <td>0.400651</td>
#       <td>0.018110</td>
#     </tr>
#     <tr>
#       <th>ДН</th>
#       <td>53</td>
#       <td>0.086319</td>
#       <td>0.003902</td>
#     </tr>
#     <tr>
#       <th>БН</th>
#       <td>43</td>
#       <td>0.070033</td>
#       <td>0.003165</td>
#     </tr>
#     <tr>
#       <th>ЦН</th>
#       <td>7</td>
#       <td>0.011401</td>
#       <td>0.000515</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Отчислен</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Основания</th>
#       <th>local_%</th>
#       <th>global_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ОО</th>
#       <td>2147</td>
#       <td>0.454777</td>
#       <td>0.158054</td>
#     </tr>
#     <tr>
#       <th>СН</th>
#       <td>1887</td>
#       <td>0.399703</td>
#       <td>0.138913</td>
#     </tr>
#     <tr>
#       <th>ДН</th>
#       <td>392</td>
#       <td>0.083033</td>
#       <td>0.028857</td>
#     </tr>
#     <tr>
#       <th>БН</th>
#       <td>260</td>
#       <td>0.055073</td>
#       <td>0.019140</td>
#     </tr>
#     <tr>
#       <th>ЦН</th>
#       <td>35</td>
#       <td>0.007414</td>
#       <td>0.002577</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Закончил</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Основания</th>
#       <th>local_%</th>
#       <th>global_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ОО</th>
#       <td>2672</td>
#       <td>0.323918</td>
#       <td>0.196702</td>
#     </tr>
#     <tr>
#       <th>СН</th>
#       <td>2425</td>
#       <td>0.293975</td>
#       <td>0.178519</td>
#     </tr>
#     <tr>
#       <th>БН</th>
#       <td>1579</td>
#       <td>0.191417</td>
#       <td>0.116240</td>
#     </tr>
#     <tr>
#       <th>ДН</th>
#       <td>1408</td>
#       <td>0.170687</td>
#       <td>0.103651</td>
#     </tr>
#     <tr>
#       <th>ЦН</th>
#       <td>165</td>
#       <td>0.020002</td>
#       <td>0.012147</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
display_side_by_side (pie (df, 'Изучаемый_Язык'),pie (df_1, 'Изучаемый_Язык'),
                      pie (df_3, 'Изучаемый_Язык'),pie (df_4, 'Изучаемый_Язык'),
                      titles=['Общая','Академ','Отчислен','Закончил'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Общая</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Изучаемый_Язык</th>
#       <th>local_%</th>
#       <th>global_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Английский язык</th>
#       <td>10470</td>
#       <td>0.770760</td>
#       <td>0.770760</td>
#     </tr>
#     <tr>
#       <th>Немецкий язык</th>
#       <td>2223</td>
#       <td>0.163648</td>
#       <td>0.163648</td>
#     </tr>
#     <tr>
#       <th>нет</th>
#       <td>826</td>
#       <td>0.060807</td>
#       <td>0.060807</td>
#     </tr>
#     <tr>
#       <th>Французский язык</th>
#       <td>54</td>
#       <td>0.003975</td>
#       <td>0.003975</td>
#     </tr>
#     <tr>
#       <th>Русский язык</th>
#       <td>11</td>
#       <td>0.000810</td>
#       <td>0.000810</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Академ</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>
#     <tr>
#       <th>5.0</th>
#       <td>75</td>
#       <td>0.015886</td>
#       <td>0.005521</td>

# %%
train = train.drop('ID', axis=1)
#train = train.drop('Код_группы', axis=1)
train = train.drop('Где_Находится_УЗ', axis=1)
train = train.drop('Страна_ПП', axis=1)
train = train.drop('Регион_ПП', axis=1)
train = train.drop('Город_ПП', axis=1)
train = train.drop('Страна_Родители', axis=1)

# %%
test = test.drop('ID', axis=1)
#test = test.drop('Код_группы', axis=1)
test = test.drop('Где_Находится_УЗ', axis=1)
test = test.drop('Страна_ПП', axis=1)
test = test.drop('Регион_ПП', axis=1)
test = test.drop('Город_ПП', axis=1)
test = test.drop('Страна_Родители', axis=1)

# %%
train.columns.values
# Out:
# array(['Код_группы', 'Год_Поступления', 'Пол', 'Основания',
#        'Изучаемый_Язык', 'Год_Окончания_УЗ', 'Общежитие', 'Село',
#        'Иностранец', 'КодФакультета', 'СрБаллАттестата', 'Статус',
#        'Возраст', 'Семья', 'Ур_образования', 'Между_поступлениями'],
#       dtype=object)

# %%
#объеденим 2 датасета для общей обработки
train = pd.concat([train, test], axis=0)
train = train.reset_index(drop=True)
train.shape
# Out:
# (20275, 16)

# %%
#Делаем общую категоризацию
def df_category (data, column):
    category = LabelEncoder()
    for i in column:
        category.fit(data[i])
        data[i] = category.transform(data[i])
        display(category.classes_)
    return data

column = ['Пол', 'Основания', 'Изучаемый_Язык']
train = df_category (train, column)
# Out:
# array(['Жен', 'Муж'], dtype=object)
# array(['БН', 'ДН', 'ОО', 'СН', 'ЦН'], dtype=object)
# array(['Английский язык', 'Немецкий язык', 'Русский язык',
#        'Французский язык', 'нет'], dtype=object)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20275 entries, 0 to 20274
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Код_группы           20275 non-null  int64
#  1   Год_Поступления      20275 non-null  float64
#  2   Пол                  20275 non-null  int32
#  3   Основания            20275 non-null  int32
#  4   Изучаемый_Язык       20275 non-null  int32
#  5   Год_Окончания_УЗ     20275 non-null  float64
#  6   Общежитие            20275 non-null  float64
#  7   Село                 20275 non-null  float64
#  8   Иностранец           20275 non-null  float64
#  9   КодФакультета        20275 non-null  float64
#  10  СрБаллАттестата      20275 non-null  float64
#  11  Статус               13584 non-null  float64
#  12  Возраст              20275 non-null  float64
#  13  Семья                20275 non-null  float64
#  14  Ур_образования       20275 non-null  int64
#  15  Между_поступлениями  20275 non-null  object
# dtypes: float64(10), int32(3), int64(2), object(1)
# memory usage: 2.2+ MB

# %%
train['Между_поступлениями']=train['Между_поступлениями'].astype('int')

# %%
#Возвращаем 2 датасета 
train['Статус'] = train['Статус'].fillna(10)

test = train[train['Статус']==10].reset_index(drop=True)
train = train[train['Статус']!=10].reset_index(drop=True)

test = test.drop('Статус', axis=1)

# %%
plt.rcParams['figure.figsize']=(15,15)

df_corr = list(set(train.columns.values))
sns.heatmap(train[df_corr].corr(), square = True, annot=True)
# Out:
# <AxesSubplot:>

# %%
#корректируем тип данных для корректной отработки модели
def type_cor (data, column):
    for i in column:
        data[i]=data[i].astype('int')
    return data

# %%
column = [
    'Код_группы',
    'Год_Поступления',
    'Год_Окончания_УЗ',
    'Общежитие',
    'Село',
    'Иностранец',
    'КодФакультета',
    'СрБаллАттестата',
    'Возраст',
    'Семья',
    'Ур_образования',
#    'Уч_Заведение'
]
train['Статус']=train['Статус'].astype('int')
train = type_cor (train, column)
test = type_cor (test, column)

# %%
#train.loc[(train['Статус'] == -1), 'Статус'] = 2
#train.loc[(train['Статус'] == 3), 'Статус'] = 0
#train.loc[(train['Статус'] == 4), 'Статус'] = 1

# %%
X = train.drop(columns=['Статус'])
y = train['Статус']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=12345)

# %%
#upsampe
def up (features, target):
    a = features[target == 2] #-1
    b = features[target == 0] #3
    c = features[target == 1] #4 
    a_1 = target[target == 2]
    b_1 = target[target == 0]
    c_1 = target[target == 1]
    f_up = pd.concat ([a]*13+[b]*3+[c]*2)
    t_up = pd.concat ([a_1]*13+[b_1]*3+[c_1]*2)
    f_up, t_up = shuffle(f_up, t_up, random_state=12345)
    return f_up, t_up
X_train, y_train = up (X_train, y_train)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Код_группы           0 non-null      int32
#  1   Год_Поступления      0 non-null      int32
#  2   Пол                  0 non-null      int32
#  3   Основания            0 non-null      int32
#  4   Изучаемый_Язык       0 non-null      int32
#  5   Год_Окончания_УЗ     0 non-null      int32
#  6   Общежитие            0 non-null      int32
#  7   Село                 0 non-null      int32
#  8   Иностранец           0 non-null      int32
#  9   КодФакультета        0 non-null      int32
#  10  СрБаллАттестата      0 non-null      int32
#  11  Возраст              0 non-null      int32
#  12  Семья                0 non-null      int32
#  13  Ур_образования       0 non-null      int32
#  14  Между_поступлениями  0 non-null      int32
# dtypes: int32(15)
# memory usage: 0.0 bytes

# %%
column_category = [
#   'ID',
   'Код_группы',
#    'Год_Поступления',
    'Пол',
    'Основания',
    'Изучаемый_Язык',
#    'Дата_Рождения',
#    'Уч_Заведение',
#    'Где_Находится_УЗ',
#    'Год_Окончания_УЗ',
#    'Пособие',
#    'Страна_ПП',
#    'Регион_ПП',
#    'Город_ПП',
    'Общежитие',
#    'Наличие_Матери',
#    'Наличие_Отца',
#    'Страна_Родители',
    'Село',
    'Иностранец',
    'КодФакультета',
#    'СрБаллАттестата',
#    'Семья',
    'Ур_образования',
] 
pool_train = Pool(X_train, y_train, cat_features = column_category)
pool_valid = Pool(X_valid, cat_features = column_category)
pool_test_solution = Pool(test, cat_features = column_category)
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-401-0ce1a5825869> in <module>
#      25     'Ур_образования',
#      26 ]
# ---> 27 pool_train = Pool(X_train, y_train, cat_features = column_category)
#      28 pool_valid = Pool(X_valid, cat_features = column_category)
#      29 pool_test_solution = Pool(test, cat_features = column_category)
#
# C:\ProgramData\Anaconda3\lib\site-packages\catboost\core.py in __init__(self, data, label, cat_features, text_features, embedding_features, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr)
#     746                     )
#     747
# --> 748                 self._init(data, label, cat_features, text_features, embedding_features, pairs, weight,
#     749                            group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     750         super(Pool, self).__init__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\catboost\core.py in _init(self, data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1267         if label is not None:
#    1268             self._check_label_type(label)
# -> 1269             self._check_label_empty(label)
#    1270             label = self._label_if_pandas_to_numpy(label)
#    1271             if len(np.shape(label)) == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\catboost\core.py in _check_label_empty(self, label)
#     855         """
#     856         if len(label) == 0:
# --> 857             raise CatBoostError("Labels variable is empty.")
#     858
#     859     def _check_label_shape(self, label, samples_count):
#
# CatBoostError: Labels variable is empty.

# %%
classes = np.unique(y_train)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train) 
class_weights = dict(zip(classes, weights))

# %%
model = CatBoostClassifier(
    task_type='GPU',
    random_state = 12345,
    iterations = 10000,
    learning_rate = 0.001,
    depth = 12,
    loss_function= 'MultiClass',
    eval_metric='TotalF1',
    grow_policy = 'Depthwise',
    min_data_in_leaf = 3000,
    class_weights = class_weights,
##    average = 'Macro',
    bootstrap_type ='Bernoulli',
##    subsample = 0.8,
##    leaf_estimation_method = 'Newton',
    verbose = 10,
    classes_count = 3,
#    ignored_features = ['Год_Поступления', 'Год_Окончания_УЗ', 'Между_поступлениями', 'Общежитие','Село',
#                        'Изучаемый_Язык','Иностранец','Семья']
    )
#model.fit(pool_train, early_stopping_rounds=500, eval_set=(X_valid, y_valid), plot=True, use_best_model=True)

# %%
pred_valid = model.predict(pool_valid)

# %%
model.get_feature_importance(prettified=True)

# %%
print(classification_report(y_valid, pred_valid))

# %%
#-1
train_1 = train.copy()
train_1.loc[(train_1['Статус'] == -1), 'Статус'] = 1
train_1.loc[(train_1['Статус'] == 3), 'Статус'] = 0
train_1.loc[(train_1['Статус'] == 4), 'Статус'] = 0

# %%
train_1.shape
train_1['Статус'].unique()
# Out:
# array([0, 1])

# %%
#3
train_2 = train.copy()
train_2.loc[(train_2['Статус'] == -1), 'Статус'] = 0
train_2.loc[(train_2['Статус'] == 3), 'Статус'] = 1
train_2.loc[(train_2['Статус'] == 4), 'Статус'] = 0

# %%
train_2.shape
# Out:
# (13584, 16)

# %%
#4
train_3 = train.copy()
train_3.loc[(train_3['Статус'] == -1), 'Статус'] = 0
train_3.loc[(train_3['Статус'] == 3), 'Статус'] = 0
train_3.loc[(train_3['Статус'] == 4), 'Статус'] = 1

# %%
train_3.shape
# Out:
# (13584, 16)

# %%
def mod (data):
    X = data.drop(columns=['Статус'])
    y = data['Статус']
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=12345)
#    def up (features, target):
#        a = features[target == 2] #-1
#        b = features[target == 0] #3
#        c = features[target == 1] #4 
#        a_1 = target[target == 2]
#        b_1 = target[target == 0]
#        c_1 = target[target == 1]
#        f_up = pd.concat ([a]*13+[b]*3+[c]*2)
#        t_up = pd.concat ([a_1]*13+[b_1]*3+[c_1]*2)
#        f_up, t_up = shuffle(f_up, t_up, random_state=12345)
#        return f_up, t_up
#    X_train, y_train = up (X_train, y_train)
    column_category = [
#       'ID',
        'Код_группы',
#        'Год_Поступления',
        'Пол',
        'Основания',
        'Изучаемый_Язык',
#        'Дата_Рождения',
#        'Уч_Заведение',
#        'Где_Находится_УЗ',
#        'Год_Окончания_УЗ',
#        'Пособие',
#        'Страна_ПП',
#        'Регион_ПП',
#        'Город_ПП',
        'Общежитие',
#        'Наличие_Матери',
#        'Наличие_Отца',
#        'Страна_Родители',
        'Село',
        'Иностранец',
        'КодФакультета',
#        'СрБаллАттестата',
#        'Семья',
        'Ур_образования',
    ] 
    pool_train = Pool(X_train, y_train, cat_features = column_category)
    pool_valid = Pool(X_valid, cat_features = column_category)
    pool_test_solution = Pool(X, cat_features = column_category)
    classes = np.unique(y_train)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train) 
    class_weights = dict(zip(classes, weights))
    model = CatBoostClassifier(
        task_type='GPU',
        random_state = 12345,
        iterations = 10000,
        learning_rate = 0.001,
        depth = 12,
#        loss_function= 'MultiClass',
        eval_metric='TotalF1',
        grow_policy = 'Depthwise',
        min_data_in_leaf = 3000,
        class_weights = class_weights,
##    average = 'Macro',
        bootstrap_type ='Bernoulli',
##    subsample = 0.8,
##    leaf_estimation_method = 'Newton',
        verbose = 10,
#        classes_count = 3,
#    ignored_features = ['Год_Поступления', 'Год_Окончания_УЗ', 'Между_поступлениями', 'Общежитие','Село',
#                        'Изучаемый_Язык','Иностранец','Семья']
    )
    model.fit(pool_train, early_stopping_rounds=500, eval_set=(X_valid, y_valid), plot=True, use_best_model=True)
    pred_valid = model.predict(pool_valid)
    model.get_feature_importance(prettified=True)
    print(classification_report(y_valid, pred_valid))
    pred = model.predict(pool_test_solution)
    return model, pred

# %%
model, pred_1 = mod (train_1)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.7947208	test: 0.8276584	best: 0.8276584 (0)	total: 72.8ms	remaining: 12m 8s
# 10:	learn: 0.7950520	test: 0.8281639	best: 0.8284166 (2)	total: 899ms	remaining: 13m 36s
# 20:	learn: 0.7958490	test: 0.8280376	best: 0.8284166 (2)	total: 1.65s	remaining: 13m 2s
# 30:	learn: 0.7958490	test: 0.8280376	best: 0.8284166 (2)	total: 2.54s	remaining: 13m 35s
# 40:	learn: 0.7956281	test: 0.8280376	best: 0.8284166 (2)	total: 3.27s	remaining: 13m 13s
# 50:	learn: 0.7956281	test: 0.8280376	best: 0.8284166 (2)	total: 3.93s	remaining: 12m 46s
# 60:	learn: 0.7956281	test: 0.8280376	best: 0.8284166 (2)	total: 4.61s	remaining: 12m 30s
# 70:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 5.39s	remaining: 12m 34s
# 80:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 6.05s	remaining: 12m 20s
# 90:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 6.77s	remaining: 12m 17s
# 100:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 7.61s	remaining: 12m 26s
# 110:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 8.64s	remaining: 12m 49s
# 120:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 9.64s	remaining: 13m 7s
# 130:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 10.6s	remaining: 13m 17s
# 140:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 11.3s	remaining: 13m 9s
# 150:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 12s	remaining: 13m 1s
# 160:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 12.7s	remaining: 12m 53s
# 170:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 13.4s	remaining: 12m 48s
# 180:	learn: 0.7957386	test: 0.8280376	best: 0.8284166 (2)	total: 14.1s	remaining: 12m 45s
# 190:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 14.8s	remaining: 12m 41s
# 200:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 15.7s	remaining: 12m 44s
# 210:	learn: 0.7957386	test: 0.8277848	best: 0.8284166 (2)	total: 16.9s	remaining: 13m 1s
# 220:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 17.6s	remaining: 12m 56s
# 230:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 18.2s	remaining: 12m 51s
# 240:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 18.9s	remaining: 12m 46s
# 250:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 19.7s	remaining: 12m 45s
# 260:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 20.4s	remaining: 12m 40s
# 270:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 21.1s	remaining: 12m 38s
# 280:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 21.8s	remaining: 12m 35s
# 290:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 22.6s	remaining: 12m 33s
# 300:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 23.2s	remaining: 12m 28s
# 310:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 23.9s	remaining: 12m 24s
# 320:	learn: 0.7957386	test: 0.8277848	best: 0.8284166 (2)	total: 24.6s	remaining: 12m 20s
# 330:	learn: 0.7957386	test: 0.8277848	best: 0.8284166 (2)	total: 25.2s	remaining: 12m 16s
# 340:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 25.9s	remaining: 12m 12s
# 350:	learn: 0.7957386	test: 0.8277848	best: 0.8284166 (2)	total: 26.5s	remaining: 12m 8s
# 360:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 27.2s	remaining: 12m 5s
# 370:	learn: 0.7956281	test: 0.8277848	best: 0.8284166 (2)	total: 27.8s	remaining: 12m 1s
# 380:	learn: 0.7957386	test: 0.8277848	best: 0.8284166 (2)	total: 28.6s	remaining: 12m 2s
# 390:	learn: 0.7957938	test: 0.8277848	best: 0.8284166 (2)	total: 29.3s	remaining: 11m 59s
# 400:	learn: 0.7958490	test: 0.8279112	best: 0.8284166 (2)	total: 29.9s	remaining: 11m 56s
# 410:	learn: 0.7960148	test: 0.8280376	best: 0.8284166 (2)	total: 30.6s	remaining: 11m 53s
# 420:	learn: 0.7961252	test: 0.8281639	best: 0.8284166 (2)	total: 31.3s	remaining: 11m 52s
# 430:	learn: 0.7949416	test: 0.8281639	best: 0.8284166 (2)	total: 31.9s	remaining: 11m 49s
# 440:	learn: 0.7949416	test: 0.8281639	best: 0.8284166 (2)	total: 32.6s	remaining: 11m 46s
# 450:	learn: 0.7949968	test: 0.8281639	best: 0.8284166 (2)	total: 33.3s	remaining: 11m 45s
# 460:	learn: 0.7949968	test: 0.8281639	best: 0.8284166 (2)	total: 34s	remaining: 11m 43s
# 470:	learn: 0.7950520	test: 0.8281639	best: 0.8284166 (2)	total: 34.7s	remaining: 11m 41s
# 480:	learn: 0.7951624	test: 0.8281639	best: 0.8284166 (2)	total: 35.3s	remaining: 11m 38s
# 490:	learn: 0.7951624	test: 0.8282903	best: 0.8284166 (2)	total: 36s	remaining: 11m 36s
# 500:	learn: 0.7951624	test: 0.8284166	best: 0.8284166 (2)	total: 36.6s	remaining: 11m 34s
# bestTest = 0.828416588
# bestIteration = 2
# Shrink model to first 3 iterations.
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.88      3883
#            1       0.17      0.86      0.29       193
#
#     accuracy                           0.80      4076
#    macro avg       0.58      0.83      0.58      4076
# weighted avg       0.95      0.80      0.85      4076

# %%
model, pred_3 = mod (train_2)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.8212607	test: 0.8691346	best: 0.8691346 (0)	total: 41.5ms	remaining: 6m 55s
# 10:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 488ms	remaining: 7m 22s
# 20:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 902ms	remaining: 7m 8s
# 30:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 1.3s	remaining: 6m 59s
# 40:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 1.7s	remaining: 6m 51s
# 50:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 2.09s	remaining: 6m 48s
# 60:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 2.59s	remaining: 7m 2s
# 70:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 3.08s	remaining: 7m 11s
# 80:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 3.48s	remaining: 7m 6s
# 90:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 3.87s	remaining: 7m 1s
# 100:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 4.27s	remaining: 6m 58s
# 110:	learn: 0.8221166	test: 0.8717561	best: 0.8717561 (2)	total: 4.65s	remaining: 6m 54s
# 120:	learn: 0.8219660	test: 0.8717561	best: 0.8717561 (2)	total: 5.04s	remaining: 6m 51s
# 130:	learn: 0.8219660	test: 0.8717561	best: 0.8717561 (2)	total: 5.45s	remaining: 6m 50s
# 140:	learn: 0.8217458	test: 0.8717561	best: 0.8717561 (2)	total: 5.85s	remaining: 6m 49s
# 150:	learn: 0.8217458	test: 0.8717561	best: 0.8717561 (2)	total: 6.26s	remaining: 6m 48s
# 160:	learn: 0.8193838	test: 0.8681332	best: 0.8717561 (2)	total: 6.67s	remaining: 6m 47s
# 170:	learn: 0.8193838	test: 0.8681332	best: 0.8717561 (2)	total: 7.09s	remaining: 6m 47s
# 180:	learn: 0.8193838	test: 0.8681332	best: 0.8717561 (2)	total: 7.52s	remaining: 6m 48s
# 190:	learn: 0.8148943	test: 0.8631964	best: 0.8717561 (2)	total: 7.96s	remaining: 6m 49s
# 200:	learn: 0.8148943	test: 0.8631964	best: 0.8717561 (2)	total: 8.47s	remaining: 6m 52s
# 210:	learn: 0.8127538	test: 0.8598206	best: 0.8717561 (2)	total: 8.94s	remaining: 6m 54s
# 220:	learn: 0.8127538	test: 0.8598206	best: 0.8717561 (2)	total: 9.43s	remaining: 6m 57s
# 230:	learn: 0.8127538	test: 0.8598206	best: 0.8717561 (2)	total: 9.91s	remaining: 6m 58s
# 240:	learn: 0.8127538	test: 0.8598206	best: 0.8717561 (2)	total: 10.5s	remaining: 7m 3s
# 250:	learn: 0.8102052	test: 0.8549833	best: 0.8717561 (2)	total: 11s	remaining: 7m 7s
# 260:	learn: 0.8102052	test: 0.8549833	best: 0.8717561 (2)	total: 11.6s	remaining: 7m 11s
# 270:	learn: 0.8102052	test: 0.8549833	best: 0.8717561 (2)	total: 12.1s	remaining: 7m 14s
# 280:	learn: 0.8102052	test: 0.8549833	best: 0.8717561 (2)	total: 12.6s	remaining: 7m 17s
# 290:	learn: 0.8102854	test: 0.8549833	best: 0.8717561 (2)	total: 13.2s	remaining: 7m 20s
# 300:	learn: 0.8102854	test: 0.8549833	best: 0.8717561 (2)	total: 13.8s	remaining: 7m 24s
# 310:	learn: 0.8102854	test: 0.8549833	best: 0.8717561 (2)	total: 14.4s	remaining: 7m 28s
# 320:	learn: 0.8102854	test: 0.8549833	best: 0.8717561 (2)	total: 15s	remaining: 7m 31s
# 330:	learn: 0.8103655	test: 0.8549833	best: 0.8717561 (2)	total: 15.6s	remaining: 7m 35s
# 340:	learn: 0.8104456	test: 0.8549833	best: 0.8717561 (2)	total: 16.2s	remaining: 7m 39s
# 350:	learn: 0.8104456	test: 0.8549833	best: 0.8717561 (2)	total: 16.8s	remaining: 7m 43s
# 360:	learn: 0.8105258	test: 0.8549833	best: 0.8717561 (2)	total: 17.5s	remaining: 7m 47s
# 370:	learn: 0.8105258	test: 0.8549833	best: 0.8717561 (2)	total: 18.1s	remaining: 7m 50s
# 380:	learn: 0.8104538	test: 0.8549833	best: 0.8717561 (2)	total: 18.8s	remaining: 7m 54s
# 390:	learn: 0.8105339	test: 0.8549833	best: 0.8717561 (2)	total: 19.8s	remaining: 8m 6s
# 400:	learn: 0.8105339	test: 0.8549833	best: 0.8717561 (2)	total: 20.5s	remaining: 8m 10s
# 410:	learn: 0.8106141	test: 0.8549833	best: 0.8717561 (2)	total: 21.1s	remaining: 8m 12s
# 420:	learn: 0.8106942	test: 0.8549833	best: 0.8717561 (2)	total: 21.8s	remaining: 8m 17s
# 430:	learn: 0.8107661	test: 0.8558864	best: 0.8717561 (2)	total: 22.5s	remaining: 8m 19s
# 440:	learn: 0.8107661	test: 0.8558864	best: 0.8717561 (2)	total: 23.1s	remaining: 8m 20s
# 450:	learn: 0.8107661	test: 0.8558864	best: 0.8717561 (2)	total: 23.7s	remaining: 8m 21s
# 460:	learn: 0.8107579	test: 0.8560633	best: 0.8717561 (2)	total: 24.3s	remaining: 8m 22s
# 470:	learn: 0.8107579	test: 0.8560633	best: 0.8717561 (2)	total: 24.9s	remaining: 8m 23s
# 480:	learn: 0.8107579	test: 0.8560633	best: 0.8717561 (2)	total: 25.5s	remaining: 8m 24s
# 490:	learn: 0.8107579	test: 0.8560633	best: 0.8717561 (2)	total: 26.1s	remaining: 8m 24s
# 500:	learn: 0.8107497	test: 0.8571513	best: 0.8717561 (2)	total: 26.8s	remaining: 8m 28s
# bestTest = 0.8717561276
# bestIteration = 2
# Shrink model to first 3 iterations.
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      2673
#            1       0.83      0.83      0.83      1403
#
#     accuracy                           0.88      4076
#    macro avg       0.87      0.87      0.87      4076
# weighted avg       0.88      0.88      0.88      4076

# %%
model, pred_4 = mod (train_3)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.8349645	test: 0.9102312	best: 0.9102312 (0)	total: 62.1ms	remaining: 10m 20s
# 10:	learn: 0.8356773	test: 0.9094832	best: 0.9102312 (0)	total: 880ms	remaining: 13m 19s
# 20:	learn: 0.8356773	test: 0.9094832	best: 0.9102312 (0)	total: 1.58s	remaining: 12m 32s
# 30:	learn: 0.8453907	test: 0.8995384	best: 0.9102312 (0)	total: 2.32s	remaining: 12m 26s
# 40:	learn: 0.8452561	test: 0.8992206	best: 0.9102312 (0)	total: 2.9s	remaining: 11m 43s
# 50:	learn: 0.8453907	test: 0.8995384	best: 0.9102312 (0)	total: 3.57s	remaining: 11m 36s
# 60:	learn: 0.8453907	test: 0.8993379	best: 0.9102312 (0)	total: 4.29s	remaining: 11m 38s
# 70:	learn: 0.8453907	test: 0.8993379	best: 0.9102312 (0)	total: 4.87s	remaining: 11m 20s
# 80:	learn: 0.8420027	test: 0.8973603	best: 0.9102312 (0)	total: 5.59s	remaining: 11m 24s
# 90:	learn: 0.8412313	test: 0.8971244	best: 0.9102312 (0)	total: 6.3s	remaining: 11m 25s
# 100:	learn: 0.8362365	test: 0.8919041	best: 0.9102312 (0)	total: 6.88s	remaining: 11m 14s
# 110:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 7.51s	remaining: 11m 9s
# 120:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 8.09s	remaining: 11m
# 130:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 8.69s	remaining: 10m 54s
# 140:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 9.28s	remaining: 10m 48s
# 150:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 9.86s	remaining: 10m 43s
# 160:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 10.5s	remaining: 10m 38s
# 170:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 11s	remaining: 10m 34s
# 180:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 11.6s	remaining: 10m 31s
# 190:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 12.2s	remaining: 10m 27s
# 200:	learn: 0.8337386	test: 0.8843044	best: 0.9102312 (0)	total: 12.8s	remaining: 10m 25s
# 210:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 13.4s	remaining: 10m 22s
# 220:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 14s	remaining: 10m 19s
# 230:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 14.6s	remaining: 10m 17s
# 240:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 15.2s	remaining: 10m 14s
# 250:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 15.9s	remaining: 10m 16s
# 260:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 16.7s	remaining: 10m 21s
# 270:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 17.3s	remaining: 10m 21s
# 280:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 17.9s	remaining: 10m 19s
# 290:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 18.6s	remaining: 10m 20s
# 300:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 19.2s	remaining: 10m 18s
# 310:	learn: 0.8337386	test: 0.8846251	best: 0.9102312 (0)	total: 19.8s	remaining: 10m 15s
# 320:	learn: 0.8337386	test: 0.8852663	best: 0.9102312 (0)	total: 20.3s	remaining: 10m 13s
# 330:	learn: 0.8337386	test: 0.8852663	best: 0.9102312 (0)	total: 20.9s	remaining: 10m 11s
# 340:	learn: 0.8337386	test: 0.8849457	best: 0.9102312 (0)	total: 21.5s	remaining: 10m 9s
# 350:	learn: 0.8337386	test: 0.8852663	best: 0.9102312 (0)	total: 22.1s	remaining: 10m 7s
# 360:	learn: 0.8337386	test: 0.8849457	best: 0.9102312 (0)	total: 22.9s	remaining: 10m 10s
# 370:	learn: 0.8337386	test: 0.8849457	best: 0.9102312 (0)	total: 23.5s	remaining: 10m 8s
# 380:	learn: 0.8337386	test: 0.8849457	best: 0.9102312 (0)	total: 24.1s	remaining: 10m 7s
# 390:	learn: 0.8337386	test: 0.8849457	best: 0.9102312 (0)	total: 24.6s	remaining: 10m 5s
# 400:	learn: 0.8337386	test: 0.8849457	best: 0.9102312 (0)	total: 25.2s	remaining: 10m 3s
# 410:	learn: 0.8337386	test: 0.8852663	best: 0.9102312 (0)	total: 25.8s	remaining: 10m 1s
# 420:	learn: 0.8338244	test: 0.8852663	best: 0.9102312 (0)	total: 26.4s	remaining: 10m
# 430:	learn: 0.8534901	test: 0.8962509	best: 0.9102312 (0)	total: 27s	remaining: 9m 58s
# 440:	learn: 0.8534901	test: 0.8962509	best: 0.9102312 (0)	total: 27.6s	remaining: 9m 58s
# 450:	learn: 0.8534901	test: 0.8962509	best: 0.9102312 (0)	total: 28.2s	remaining: 9m 57s
# 460:	learn: 0.8534901	test: 0.8962509	best: 0.9102312 (0)	total: 28.8s	remaining: 9m 55s
# 470:	learn: 0.8534901	test: 0.8968881	best: 0.9102312 (0)	total: 29.4s	remaining: 9m 54s
# 480:	learn: 0.8534901	test: 0.8968881	best: 0.9102312 (0)	total: 30s	remaining: 9m 53s
# 490:	learn: 0.8534901	test: 0.8968881	best: 0.9102312 (0)	total: 30.6s	remaining: 9m 52s
# 500:	learn: 0.8534901	test: 0.8968881	best: 0.9102312 (0)	total: 31.3s	remaining: 9m 52s
# bestTest = 0.9102311731
# bestIteration = 0
# Shrink model to first 1 iterations.
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90      1596
#            1       0.91      0.96      0.94      2480
#
#     accuracy                           0.92      4076
#    macro avg       0.93      0.91      0.92      4076
# weighted avg       0.92      0.92      0.92      4076

# %%
train['1'] = pred_1
train['3'] = pred_2
train['4'] = pred_4
train.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-422-60c876b12bdd> in <module>
#       1 train['1'] = pred_1
# ----> 2 train['3'] = pred_2
#       3 train['4'] = pred_4
#       4 train.head(100)
#
# NameError: name 'pred_2' is not defined

# %%
train['134'] = train['1']+train['3']+train['4']
train['134'].value_counts()
